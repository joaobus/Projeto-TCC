# %%
from classes.SistemaFisico import Misturador
from classes.GeradorDeDisturbios import GeradorDeDisturbios

# %%
# Instanciando o sistema físico
misturador = Misturador()
misturador.listar_parametros()

# Os parâmetros podem ser acessados e editados no arquivo params.py
# Out:
#         Entradas:
#             F0 = 2.0 L/s       Fa0 = 2.0 L/s     Ca0 = 1 mol/L
#         Saídas:
#             F = 4 L/s         Ca = 0.5 L/s
#         Dimensões:
#             V = 10.0 L
#         Setpoints:
#             Vset = 10.0 L     Caset = 0.5 mol/L
#         Variáveis no setpoint:
#             F = 4 L/s F0 = 2.0 L/s
#         Constantes do controlador:
#             Controlador de nível:
#                 Kc = -5, Ti = 1, Td = 0
#             Controlador de concentração:
#                 Kc = -5, Ti = 0.1, Td = 0

# %%
# Verificando estado estacionário

nulo = GeradorDeDisturbios().sinal_nulo()       ## Instanciando um distúrbio nulo
misturador.simular(nulo).plotar_graficos()

# %%
# Colocando o sistema no estado estacionário
misturador.estado_estacionario()
misturador.simular(nulo).plotar_graficos()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Colocando o sistema no estado estacionário
# ----> 2 misturador.estado_estacionario()
#       3 misturador.simular(nulo).plotar_graficos()
#
# File d:\Ryan\Documents\Python\TCC\Projeto-TCC\src\classes\SistemaFisico.py:218, in Misturador.estado_estacionario(self)
#     215 [Vset,Caset] = self.setpoints
#     216 [F0,Fa0,Ca0] = self.entradas
# --> 218 nulo = GeradorDeDisturbios(Vset).sinal_nulo()
#     219 self.simular(nulo)
#     221 [tempoV,VV,FV,F0V,CaV,Fa0V] = self.vetores_para_plotagem
#
# TypeError: GeradorDeDisturbios.__init__() takes 1 positional argument but 2 were given

# %%
# Instanciando um distúrbio degrau
degrau = GeradorDeDisturbios().degrau(intensidade=0.1,inicio=20) # Intensidade = 10% do setpoint
misturador.simular(degrau).plotar_graficos()

# %%
# Erro na função objetivo
print(misturador.erro())
# Out:
# 0.0
